# %% [markdown]
# ### Introduction

# %% [markdown]
# ```js
# it is a collection or group of nodes
# Each node contains a data and reference whihc contains the address of next node

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Single Linked List

# %%
class SinglyNode:
    def __init__(self,val,next=None):
        self.val = val
        self.next = next
    def __str__(self):
        return str(self.val)
    
Head = SinglyNode(1)
A =SinglyNode(3)
B =SinglyNode(4)
C = SinglyNode(7)

Head.next = A
A.next = B
B.next = C

# %%
# Traversal
curr = Head
while curr:
    print(curr)
    curr = curr.next
# Out:
# 1
# 3
# 4
# 7

# %%
# Display the list -- O(n)

def display(head):
    curr = Head
    elements = []
    while curr:
        elements.append(str(curr.val))
        curr = curr.next
    print("--> ".join(elements))

# %%
display(Head)
# Out:
# 1--> 3--> 4--> 7

# %%
# Searching

def search(head,val):
    curr = head
    while curr:
        if val == curr.val:
            return True
        curr = curr.next

    return False

search(Head,7)
# Out:
# True

# %% [markdown]
# # Double Linked List

# %%
class DoublyNode:
    def __init__(self,val,next=None,prev=None):
        self.val = val
        self.next = next
        self.prev = prev
    def __str__(self):
        return self.val

# %%
head = tail =DoublyNode(1)

# %%
# Display double linked list
def display(head):
    curr = head
    elements = []
    while curr:
        elements.append(str(curr.val))
        curr =curr.next
    print('<-->'.join(elements))

display(head)
# Out:
# 1

# %%
# Insert at beginning
def insert_at_beginning(head,tail,val):
    new_node = DoublyNode(val,next=head)
    head.prev = new_node
    return new_node,tail

head,tail = insert_at_beginning(head,tail,3)
display(head)
# Out:
# 3<-->1

# %%
# Insert at end
def insert_at_end(head,tail,val):
    new_node = DoublyNode(val,prev=tail)
    tail.next = new_node
    return head,new_node

head,tail = insert_at_end(head,tail,8)
display(head)
# Out:
# 3<-->1<-->8
