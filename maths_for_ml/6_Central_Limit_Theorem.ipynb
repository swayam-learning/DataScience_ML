# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_size = 10000  # Size of population
sample_size = 100  # Size of each sample
num_samples = 1000  # Number of samples to take

# Generate a population with a non-normal distribution (exponential for example)
population = np.random.exponential(scale=1.0, size=population_size)

# Function to calculate sample means
def calculate_sample_means(population, sample_size, num_samples):
    sample_means = []
    for _ in range(num_samples):
        sample = np.random.choice(population, size=sample_size, replace=False)
        sample_mean = np.mean(sample)
        sample_means.append(sample_mean)
    return sample_means

# Calculate sample means
sample_means = calculate_sample_means(population, sample_size, num_samples)

# Plotting
plt.figure(figsize=(10, 6))
plt.hist(sample_means, bins=30, density=True, color='r', edgecolor='black')
plt.title('Distribution of Sample Means (Central Limit Theorem)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.show()

# %% [raw]
# Analysis of the Provided Code:
# Population Generation:
#
# population = np.random.exponential(scale=1.0, size=population_size): Generates a population of 10,000 data points (population_size) from an exponential distribution with a scale parameter of 1.0. The exponential distribution is chosen as an example of a non-normal distribution.
# Sampling and Sample Means Calculation:
#
# The function calculate_sample_means iterates num_samples times.
# Each iteration selects sample_size random samples (np.random.choice()) from the population without replacement (replace=False).
# It calculates the mean of each sample (np.mean(sample)) and appends it to sample_means.
# Histogram Plotting:
#
# plt.hist(sample_means, bins=30, density=True, alpha=0.75, color='b', edgecolor='black'): Plots a histogram of sample_means.
# The histogram is set to show 30 bins (bins=30), normalized to form a probability density (density=True), with 75% transparency (alpha=0.75), blue bars (color='b'), and black edges (edgecolor='black').
# Why This Represents the Central Limit Theorem:
# Sample Means Distribution: According to the CLT, as the number of samples (num_samples) increases, the distribution of sample means (sample_means) tends to approximate a normal distribution, regardless of the original distribution of the population (exponential in this case).
#
# Normal Approximation: The histogram of sample_means shows a bell-shaped curve, resembling a normal distribution. This aligns with the CLT's prediction that sample means from a population, even if the population itself is not normally distributed, will tend to follow a normal distribution as the sample size increases.
#
# Assurance of CLT Application:
# Statistical Inference: The simulation effectively demonstrates the principles of the CLT through the generation of sample means from a non-normal population distribution (exponential).
#
# Visualization: The histogram plot visually confirms that as num_samples increases, the distribution of sample_means becomes more normal-like, which is a hallmark of the CLT.
#
# Conclusion:
# While no simulation can definitively prove a theorem, the provided code aligns with the expectations and principles of the Central Limit Theorem. It illustrates how sample means from a non-normal population distribution tend to follow a normal distribution as the sample size increases, providing a practical demonstration of the CLT's predictive power in statistical analysis.
