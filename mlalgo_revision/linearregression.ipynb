# %%
class MeraLinearRegression:
    def __init__(self):
        self.m = None
        self.b = None
    def fit(self,X_train,y_train):
        num = 0
        dem = 0
        for i in range(X_train.shape[0]):
            num = num + ((X_train[i]-X_train.mean())*(y_train[i]-y_train.mean()))
            dem  = dem + ((X_train[i]-X_train.mean())*(X_train[i]-X_train.mean()))
            self.m = num/dem
            self.b = y_train.mean() - self.m*X_train.mean()
            print(self.m)
            print(self.b)

    def predict(self,X_test):
        return self.m*X_test + self.b

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\OneDrive\codes\python\Learn_ML\1. Datasets\placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
from sklearn.model_selection import train_test_split
X_train , X_test ,y_train,y_test = train_test_split(df.iloc[:,0].values,df.iloc[:,-1].values,train_size=0.75,random_state=42)

# %%
X_train.shape
# Out:
# (150,)

# %%
lr = MeraLinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# 0.967362924281984
# -3.7793994778067863
# 1.002092513035272
# -4.023011335769683
# 0.649093200272228
# -1.5468858897495523
# 0.5491996996415656
# -0.8461795997924164
# 0.5469318494835133
# -0.8302716892637529
# 0.610456294977564
# -1.2758660296632889
# 0.5530228388307085
# -0.8729971370726322
# 0.5981651464485185
# -1.1896493586013475
# 0.6037507698471746
# -1.2288299001186673
# 0.5973352706016941
# -1.1838281668112702
# 0.5959294151846112
# -1.1739667471262947
# 0.5603481258397274
# -0.9243806069736289
# 0.581307468679369
# -1.0714006159670562
# 0.530383448981343
# -0.7141923823279299
# 0.5308615651573984
# -0.7175461441820761
# 0.5193634639438773
# -0.6368923299497924
# 0.5145759020624004
# -0.6033098175467764
# 0.5407992684473159
# -0.7872544951659783
# 0.5389450564423365
# -0.774248063249984
# 0.5491073042508987
# -0.8455314892447374
# 0.5123136583382848
# -0.5874412335358432
# 0.5104015236436147
# -0.5740285009822563
# 0.49531716837701667
# -0.46821878815286233
# ...

# %%
lr.predict(X_test)
# Out:
# array([2.78658779, 3.14067821, 3.2035007 , 2.39823057, 3.52903544,
#        3.76890314, 3.16923389, 2.55243123, 3.18065616, 3.49476862,
#        1.91849517, 2.35825262, 3.68894724, 2.76374325, 3.47763522,
#        3.04930004, 2.33540807, 3.20921184, 2.18691855, 3.31772342,
#        2.46105306, 2.90652164, 3.32343455, 2.87796597, 3.34056796,
#        2.20405195, 1.43304863, 2.71805417, 3.18636729, 2.33540807,
#        3.74605859, 2.963633  , 3.6832361 , 2.98076641, 2.59812032,
#        3.35199023, 2.4838976 , 3.07785572, 4.17439377, 2.963633  ,
#        3.10070026, 3.11783367, 3.9231038 , 2.72947644, 1.9242063 ,
#        2.95792187, 3.08356685, 3.27203433, 1.77000564, 3.34627909])

# %%
from sklearn.linear_model import LinearRegression
lr1 = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:1],df.iloc[:,-1],test_size=0.25,random_state=42)

# %%
lr1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(X_test)

# %%
y_predict
# Out:
#          cgpa
# 95   2.786588
# 15   3.140678
# 30   3.203501
# 158  2.398231
# 128  3.529035
# 115  3.768903
# 69   3.169234
# 170  2.552431
# 174  3.180656
# 45   3.494769
# 66   1.918495
# 182  2.358253
# 165  3.688947
# 78   2.763743
# 186  3.477635
# 177  3.049300
# 56   2.335408
# 152  3.209212
# 82   2.186919
# 68   3.317723
# 124  2.461053
# 16   2.906522
# 148  3.323435
# 93   2.877966
# 65   3.340568
# 60   2.204052
# 84   1.433049
# 67   2.718054
# 125  3.186367
# 132  2.335408
# 9    3.746059
# 18   2.963633
# 55   3.683236
# 75   2.980766
# 150  2.598120
# 104  3.351990
# 135  2.483898
# 137  3.077856
# 164  4.174394
# 76   2.963633
# 79   3.100700
# 197  3.117834
# 38   3.923104
# 24   2.729476
# 122  1.924206
# 195  2.957922
# 29   3.083567
# 19   3.272034
# 143  1.770006
# 86   3.346279

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score
print("Mean aboslute error",mean_absolute_error(y_test,y_predict))
print("Mean Squared error ",mean_squared_error(y_test,y_predict))
print("Root Mean Squared Error",root_mean_squared_error(y_test,y_predict))
print("R2 score",r2_score(y_test,y_predict))
# Out:
# Mean aboslute error 0.24266327437416052
# Mean Squared error  0.09122322472141597
# Root Mean Squared Error 0.3020318273318492
# R2 score 0.7774721122516276

# %%
# adjusted r2 score
adjusted_r2_score = 1 - (((1-r2_score(y_test,y_predict))*(df.shape[0]-1))/((df.shape[0]-1-1)))

# %%
adjusted_r2_score
# Out:
# 0.7763482340306762
