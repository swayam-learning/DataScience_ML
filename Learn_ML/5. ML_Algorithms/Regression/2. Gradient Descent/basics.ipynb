# %% [markdown]
# #### Gradient Descent
# B new = B old - n*slope
#
#
# ##### n * slope is called as step size, n being the learning rate

# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4 ,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)
# we have n_features = 1 that is 1 column
# n_samples = 4 means(matlab)-->4 rows
# n_informative = 1 ,1 feature affects in the making of target variable
# noise = 80 the amt of std used to make target variable

# %%
X
# Out:
# array([[-0.71239066],
#        [ 0.45181234],
#        [-0.04450308],
#        [ 0.75376638]])

# %%
y
# Out:
# array([  7.21786552,  16.04609925, -27.83756166, 144.36688189])

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red")
plt.show()

# %% [markdown]
# ### Iteration 0

# %%
# for a slope of 78.35 now we try with intercept b = 0
b = 0
y_pred = (78.35*X+b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label="Ordinary Least Square")
plt.plot(X,y_pred,color="blue",label="b=0")
plt.legend()
plt.show()

# %% [markdown]
# #### fromula for slope
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Iteration 1

# %% [markdown]
# #### Calculating Loss slope

# %%
m=78.35
loss_slope = -2 * np.sum(y-m*X.ravel()-b)
loss_slope
# Out:
# -209.27763408209216

# %% [markdown]
# #### Calculating the step size

# %%
# learning rate
lr = 0.1 

step_size = loss_slope*lr
step_size
# Out:
# -20.927763408209216

# %% [markdown]
# #### Calculating the new intercept

# %%
b = b - step_size
# b new = b old - loss_slope * learning_rate 
b
# Out:
# 20.927763408209216

# %%
y_pred1 = ((78.35*X)+b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label="Ordinary Least Square")
plt.plot(X,y_pred1,color="#00a65a",label="b={}".format(b))
plt.plot(X,y_pred,color="#A3E4D7",label="b=0")
plt.legend()
plt.show()

# %% [markdown]
# ### Iteration 2

# %% [markdown]
# ### Repeating the same steps again for better results

# %%
loss_slope = -2 * np.sum(y-m*X.ravel()-b)
loss_slope
# Out:
# -41.85552681641843

# %%
lr = 0.1 

step_size = loss_slope*lr #(n)
step_size
# Out:
# -4.185552681641844

# %%
b = b - step_size
# b new = b old - loss_slope * learning_rate 
b
# Out:
# 25.11331608985106

# %%
y_pred2 = ((78.35*X)+b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label="Ordinary Least Square")
plt.plot(X,y_pred2,color="#00a65a",label="b={}".format(b))
plt.plot(X,y_pred1,color="#A3E4D7",label="b=20.927")
plt.plot(X,y_pred,color="#A3E4D7",label="b=0")
plt.legend()
plt.show()

# %% [markdown]
# ### Iteration 3

# %%
loss_slope = -2 * np.sum(y-m*X.ravel()-b)
loss_slope
# Out:
# -8.371105363283675

# %%
lr = 0.1 

step_size = loss_slope*lr
step_size
# Out:
# -0.8371105363283675

# %%
b = b - step_size
# b new = b old - loss_slope * learning_rate 
b
# Out:
# 25.95042662617943

# %%
y_pred3 = ((78.35*X)+b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red",label="Ordinary Least Square")
plt.plot(X,y_pred3,color="#00a65a",label="b={}".format(b))
plt.plot(X,y_pred2,color="#A3E4D7",label="b=25.1133")
plt.plot(X,y_pred1,color="#A3E4D7",label="b=20.927")
plt.plot(X,y_pred,color="#A3E4D7",label="b=0")
plt.legend()
plt.show()

# %%
b = -100
lr = 0.01
m = 78.35

epochs = 100
for i in range(epochs):
    loss_slope = -2 *np.sum(y-m*X.ravel()-b)
    b=b-(lr*loss_slope)
    y_pred=m*X-b

    plt.plot(X,y_pred)
plt.scatter(X,y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### b_new = b_old - lr * b_slope
# ##### m_new = m_old - lr * b_slope
