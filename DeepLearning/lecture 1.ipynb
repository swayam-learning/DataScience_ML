# %% [markdown]
# #### Deep learning is a sub-field of ai and ml that is inspired by the structure if human brain
# #### Deep learning algorithms attempt to draw similar conclusions as humans would by continually analyzing data with a given logical structure called Neural Network.
# ![image.png](attachment:image.png)

# %% [markdown]
# deep learning can be applied in different fields and the performance is whast makes it famous

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Deep Learning fails at interpretability because it is a black-box

# %% [markdown]
# ### Types of Neural Networks
# 1. Multilayer perceptron  ------ Supervised Problems
# 2. Convolutional Neural Network ------ Image Processing
# 3. Recurrent Neural Network ---- NLP applications
# 4. Auto Encoders
# 5. Generative Adverserial Networks ---- genai
