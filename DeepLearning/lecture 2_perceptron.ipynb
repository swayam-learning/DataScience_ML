# %% [markdown]
# ## Perceptron

# %% [markdown]
# #### Algorithm used for supervised machine learning
# #### Activation functions are used to give a range to the mathematical equation
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# #### weights tell us about the feature importance

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------
# ### Perceptron is a binary classifer , a line which divides the classes into regions
# ![image.png](attachment:image.png)
#
# Perceptron can only work on linear dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\codes\DSML\DeepLearning\datasets\placement.csv")

# %%
print(df.shape)
df.head()
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x = df["cgpa"],y=df["resume_score"],hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
x =  df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# w1,w2
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# b
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values,y.values,clf=p,legend=2)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
